# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# !pip install gmaps
# !jupyter nbextension enable --py --sys-prefix gmaps

# %%
# Dependencies
from census import Census
from api_keys import (weather_api_key, g_key)
import gmaps
import numpy as np
import pandas as pd
import requests
import time
import json
from scipy.stats import linregress
from matplotlib import pyplot as plt
from citipy import citipy
import pprint

#REMOVE THESE! TEsting api import
print(weather_api_key)
print(g_key)

# %%
#created varaibles for hiolding data
cities= []
lats=[]
lons=[]

#function to retrieve random coordinates. limits given by natural lat and lon ranges
lats = np.random.uniform(-90,91,size=(500))
lons = np.random.uniform(-180,181,size=(500))
coordinates = zip(lats,lons)

#smple function to iterate the coordinates variable, looking for city bames
for c in coordinates:
    city_nme=citipy.nearest_city(c[0],c[1]).city_name
    cities.append(city_nme)
#small test to see if appending city names is working
#print(raw_cities)
#print(f"there are{len(raw_cities)} raw cities")
#cities = set(raw_cities)
#print(f"there are{len(cities)}  cities after duplicates are removed")

len(cities)
# Out:
# 500

# %%
#building blocks for api retireval

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#variables for holding weather data for each city
temps=[]
cloud=[]
wind_spd=[]
humid=[]
date=[]

#iteration to track number of retrievals
iteration = 0
#loop to iterate city list, seeking for the relevant information from the Open Weather API, holding it in the variables
for city in cities:
 
    try:
        city_weather = requests.get(query_url + city).json()
        temps.append(city_weather['main']['temp_max'])
        cloud.append(city_weather['clouds']['all'])
        wind_spd.append(city_weather['wind']['speed'])
        humid.append(city_weather['main']['humidity'])
        date.append(city_weather['dt'])
        iteration = iteration + 1
        print(f"Processing {city} city number {iteration} of {len(cities)}")
#experienced MANY issues with arrays of unequal length. Current solution is add a placeholder value, clearly indicating it has to be removed, to maintain array length
    except: 
        print(f"I don't like {city} - better move on to next city")
        temps.append("Null")
        cloud.append("Null")
        wind_spd.append("Null")
        humid.append("Null")
        date.append("Null")

        
        #test Array lengths
#print(len(cities))
#print(len(lats))
#print(len(lons))
#print(len(wind_spd))
#print(len(humid))        
#print(len(date))       

#city_df = pd.DataFrame({"City":cities,"Lat":lats,"Lon":lons, "Temp":temps,"Cloudiness": cloud, "Wind Speed": wind_spd, "Humidity":humid,"Date":date})    
    
#city_df.head(30)        
#print(json.dumps(city_weather, indent=4, sort_keys=True))
# Out:
# Processing bluff city number 1 of 500
# Processing punta arenas city number 2 of 500
# Processing bambous virieux city number 3 of 500
# Processing vaini city number 4 of 500
# Processing san patricio city number 5 of 500
# Processing harlingen city number 6 of 500
# Processing victoria city number 7 of 500
# Processing thompson city number 8 of 500
# Processing vaini city number 9 of 500
# Processing sao filipe city number 10 of 500
# Processing severnyy city number 11 of 500
# Processing praia city number 12 of 500
# Processing dong xoai city number 13 of 500
# Processing khatanga city number 14 of 500
# Processing nichinan city number 15 of 500
# Processing punta arenas city number 16 of 500
# Processing arona city number 17 of 500
# Processing jawar city number 18 of 500
# Processing butaritari city number 19 of 500
# Processing yellowknife city number 20 of 500
# Processing longyearbyen city number 21 of 500
# Processing kapaa city number 22 of 500
# Processing ushuaia city number 23 of 500
# Processing port alfred city number 24 of 500
# Processing mataura city number 25 of 500
# Processing riyadh city number 26 of 500
# Processing new norfolk city number 27 of 500
# Processing ahipara city number 28 of 500
# Processing pisco city number 29 of 500
# Processing jamestown city number 30 of 500
# Processing new cebu city number 390 of 500
# Processing asau city number 391 of 500
# I don't like taolanaro - better move on to next city
# Processing ahipara city number 392 of 500
# Processing hami city number 393 of 500
# Processing kahului city number 394 of 500
# Processing faanui city number 395 of 500
# Processing upernavik city number 396 of 500
# Processing rikitea city number 397 of 500
# Processing murud city number 398 of 500
# Processing puerto ayora city number 399 of 500
# I don't like mys shmidta - better move on to next city
# Processing kodiak city number 400 of 500
# Processing mataura city number 401 of 500
# Processing puerto ayora city number 402 of 500
# Processing tuktoyaktuk city number 403 of 500
# Processing katsuura city number 404 of 500
# Processing tuktoyaktuk city number 405 of 500
# Processing khatanga city number 406 of 500
# Processing kaitangata city number 407 of 500
# Processing busselton city number 408 of 500
# Processing albany city number 409 of 500
# Processing pevek city number 410 of 500
# Processing faanui city number 411 of 500
# Processing mataura city number 412 of 500
# Processing rikitea city number 413 of 500
# Processing rikitea city number 414 of 500
# Processing ilulissat city number 415 of 500
# I don't like kuche - better move on to next city
# Processing chuy city number 416 of 500
# Processing anito city number 417 of 500
# Processing dikson city number 418 of 500
# Processing tecolutilla city number 419 of 500
# Processing poum city number 420 of 500
# Processing dunedin city number 421 of 500
# Processing rikitea city number 422 of 500
# Processing vardo city number 423 of 500
# Processing provideniya city number 424 of 500
# Processing ushuaia city number 425 of 500
# Processing wonthaggi city number 426 of 500
# Processing sorland city number 427 of 500
# Processing hilo city number 428 of 500
# Processing saint-philippe city number 429 of 500
# Processing saskylakh city number 430 of 500
# Processing san andres city number 431 of 500
# Processing bud city number 432 of 500
# I don't like lolua - better move on to next city
# Processing qaqortoq city number 433 of 500
# Processing khatanga city number 434 of 500
# Processing rikitea city number 435 of 500
# I don't like illoqqortoormiut - better move on to next city
# Processing maldonado city number 436 of 500
# Processing kisangani city number 437 of 500
# Processing christchurch city number 438 of 500
# Processing rosarito city number 439 of 500
# Processing jiwani city number 440 of 500
# Processing avarua city number 441 of 500
# Processing mutis city number 442 of 500
# Processing bambous virieux city number 443 of 500
# Processing hobart city number 444 of 500
# Processing atuona city number 445 of 500
# Processing tuktoyaktuk city number 446 of 500
# Processing saskylakh city number 447 of 500
# Processing chapadinha city number 448 of 500
# Processing kapaa city number 449 of 500
# Processing tuktoyaktuk city number 450 of 500
# Processing qaanaaq city number 451 of 500
# I don't like barentsburg - better move on to next city
# Processing akdagmadeni city number 452 of 500
# Processing butaritari city number 453 of 500
# Processing pringsewu city number 454 of 500
# Processing punta arenas city number 455 of 500
# Processing hermanus city number 456 of 500
# Processing karasburg city number 457 of 500
# Processing kachug city number 458 of 500
# Processing coihueco city number 459 of 500
# Processing kapaa city number 460 of 500
# Processing ushuaia city number 461 of 500
# Processing tamale city number 462 of 500
# Processing rikitea city number 463 of 500
# Processing mayya city number 464 of 500
# Processing kuytun city number 465 of 500
# Processing airai city number 466 of 500
# Processing dhenkanal city number 467 of 500
# I don't like jujuy - better move on to next city
# Processing buchanan city number 468 of 500
# I don't like rawannawi - better move on to next city

# %%
#create DF to hold data
city_df = pd.DataFrame({"City":cities,"Lat":lats,"Lon":lons, "Max_Temp":temps,"Cloudiness": cloud, "Wind_Speed": wind_spd, "Humidity":humid,"Date":date})    

len(city_df)

city_no_duplicates = city_df.drop_duplicates(["City"],keep = 'first', inplace=False,ignore_index=False)

len(city_no_duplicates)

#len(city_df)
#len(city_df_clean)
#duplicated_cities = city_df.loc[city_df.duplicated(subset=['City']),'City'].unique()
#duplicated_cities
# Out:
# 276

# %%
   
city_df_clean = city_no_duplicates[city_no_duplicates["Date"]!= "Null"]    


export_csv = city_df_clean.to_csv(r'output_data\cities.csv', index = None, header=True)
city_df_clean.head(10)
# Out:
#                City        Lat         Lon Max_Temp Cloudiness Wind_Speed  \
# 0             bluff -72.550564  170.357475       59         91      15.99
# 1      punta arenas -66.347693 -112.259443     48.2         40      24.16
# 2   bambous virieux -31.216687   72.745202       82         40      10.36
# 3             vaini -78.005113 -179.523509     84.2         40       6.91
# 4      san patricio   0.792950 -113.878197     48.2          1       9.22
# 5         harlingen  55.645732    4.507434    51.01          1       4.61
# 6          victoria  -7.168254   56.190591       55         19       1.01
# 7          thompson  71.666350  -94.630720        5          1        2.3
# 9        sao filipe  10.227601  -32.052263    73.15         83       11.9
# 10         severnyy  70.039812   64.136957       32         75       2.24
#
#    Humidity        Date
# 0        72  1610168681
# 1        71  1610168681
# 2        78  1610168681
# 3        84  1610168681
# 4        81  1610168682
# 5        87  1610168682
# 6        28  1610168528
# 7        92  1610168682
# 9        77  1610168683
# 10       93  1610168683

# %%
#check for values over 100 for humidity
print(np.max(city_df_clean["Humidity"]))

city_df_clean.head()

#find the indices for humidity values greater than 100
indices = np.where(city_df_clean["Humidity"] > 100)
print(indices[0])

#new df after dropping values using index
clean_city_df = city_df_clean.drop(indices[0],axis =0)

#convert all data to numeric

cols = clean_city_df.columns[clean_city_df.dtypes.eq(object)]
clean_city_df[cols] = clean_city_df[cols].apply(pd.to_numeric, errors= 'coerce')

clean_city_df.dtypes


len(clean_city_df)

#clean_city_df.head(15)
# Out:
# 100
# []
# 256

# %%
#Scatterplots - Temperature (F) vs. Latitude

plt.scatter(clean_city_df["Lat"],clean_city_df["Max_Temp"])
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.suptitle("Latitude vs Max Temperature (F)", fontsize=16, fontweight="bold")
plt.savefig("output_data/chart1.png")
plt.show()

# %% [markdown]
# As we look at the relationship between temperature in Farenheit and Latitude, we can observe that the highest MAx Temperatures take place closer to Latitude 0, which represents the equator. The further away from zero, the closer a latitude point is to either pole. We can observe quickly decreasing temperatres in the highest latitudes, very close to the North Pole. The southernmost areas of the Suthern Hmisphere are very sparesely populated, hence the reduced number of datapoints.

# %%
plt.scatter(clean_city_df["Lat"],clean_city_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.suptitle("Latitude vs Humidity %", fontsize=16, fontweight="bold")
plt.savefig("output_data/chart2.png")
plt.show()

# %%
plt.scatter(clean_city_df["Lat"],clean_city_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.suptitle("Latitude vs Cloudiness %", fontsize=16, fontweight="bold")
plt.savefig("output_data/chart3.png")
plt.show()

# %%
plt.scatter(clean_city_df["Lat"],clean_city_df["Wind_Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.suptitle("Latitude vs Wind Speed MPH", fontsize=16, fontweight="bold")
plt.savefig("output_data/chart4.png")
plt.show()
